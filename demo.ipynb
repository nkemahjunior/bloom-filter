# %% [markdown]
# # Bloom Filter — Concepts of Data Science 2025-2026
#
# **Team members:**
# - Junior Kaving
# - Rexford Holland
#
# ## Overview
# This notebook demonstrates and tests our Bloom filter implementation.

# %%
# Temporary stub - to be replaced once teammate pushes bloom_filter.py
class BloomFilter:
    def __init__(self, size, num_hashes):
        self.size = size
        self.num_hashes = num_hashes
        self.bit_array = [0] * size

    def insert(self, item):
        pass

    def search(self, item):
        return False
